# %% [markdown]
# ## Đề bài:
#
# Có N bài báo 1, 2, …, N khoa học cần được phân cho M nhà khoa học
# 1, 2, …, M để nhận xét phản biện. Tùy thuộc vào lĩnh vực chuyên môn
# của bài báo và của nhà khoa học mà mỗi bài báo i sẽ tương ứng với 1
# danh sách L(i) các nhà khoa học có thể tham gia phản biện. Mỗi bài báo
# cần được phân công cho ít nhất K nhà khoa học phản biện để đảm bảo
# tính tin cậy. Hãy xây dựng phương án phân công phản biện sao cho số
# lượng bài báo nhiều nhất phân cho một nhà khoa học nào đó phải ít
# nhất.
#
# • Input
# • Dòng 1: ghi N, M, và K
# • Dòng thứ i + 1 (i = 1,…, N): ghi giá trị qi và qi số nguyên dương trong
# danh sách L(i)

# %%
from ortools.linear_solver.pywraplp import Variable
from ortools.sat.python import cp_model
import itertools
import time
from generate_data import *

generate()
start_time = time.time()

N,M,K,A = read_data('data_sample.txt')
'''
print('N',N)
print('M',M)
print('K',K)
print('A',A)
'''

from ortools.sat.python import cp_model
class VarArraySolutionPrinter(cp_model.CpSolverSolutionCallback):
    def __init__(self,variables):
        cp_model.CpSolverSolutionCallback.__init__(self)
        self.__variables = variables
        self.__solution_count = 0
        
    def  on_solution_callback(self):
        self.__solution_count += 1
        for v in self.__variables:
            print('%s = %i'%(v,self.Value(v)),end = ' ')
        print()
    def solution_count():
        return self.__solution_count

model = cp_model.CpModel()

X = [[model.NewIntVar(0, 1, f'X[{i}][{j}]') for j in range(M)] for i in range(N)]
max_papers = model.NewIntVar(K,N+1,'max_papers')

#điểu kiện số chuyên gia nghiên cứu 1 bài báo lớn hơn hoặc bằng K
for i in range(N):
    model.Add(sum(X[i][j] for j in range(M)) >= K)

#điều kiện chuyên gia nghiên cứu bài báo phải thuộc đúng lĩnh vực đó
for i in range(N):
    for j in range(M):
        if A[i][j] == 0:
            model.Add(X[i][j] == 0)

#add constaint    
for j in range(M):
    model.Add(sum(X[i][j] for i in range(N)) <= max_papers)
    
model.Minimize(max_papers)
    
solver = cp_model.CpSolver()
status = solver.Solve(model)

if status == cp_model.OPTIMAL :
    print('max papers for each scientist = ', solver.Value(max_papers))
    for j in range(M):
        print('chuyen gia' ,j+1,'thuc hien bai bao: ',end = '')
        for i in range(N):     
            if solver.BooleanValue(X[i][j]):
                print(i+1, end = ' ')
        print()
else:
    print('No solution found.')

print('time:',round(time.time()-start_time,5),'s')
# Out:
# max papers for each scientist =  15
# chuyen gia 1 thuc hien bai bao: 6 7 10 22
# chuyen gia 2 thuc hien bai bao: 4 26
# chuyen gia 3 thuc hien bai bao: 1 10 12 21 24 38 40
# chuyen gia 4 thuc hien bai bao: 12 17 23 32 34 38 39 40
# chuyen gia 5 thuc hien bai bao: 17 23 26 27 39
# chuyen gia 6 thuc hien bai bao: 3 6 7 9 10 14 16 29 36 39
# chuyen gia 7 thuc hien bai bao: 1 8 17 20 24 25
# chuyen gia 8 thuc hien bai bao: 2 6 8 10 14 18 27 31 38
# chuyen gia 9 thuc hien bai bao: 10 12 19 20 26 28 29 39 40
# chuyen gia 10 thuc hien bai bao: 1 2 3 8 17 22 23 34 35 39
# chuyen gia 11 thuc hien bai bao: 5 7 8 11 18 23 24 30 40
# chuyen gia 12 thuc hien bai bao: 1 2 8 15 20 23 25 26 32 33 35 36 38
# chuyen gia 13 thuc hien bai bao: 2 5 9 12 13 14 16 18 19 20 26 30 32 40
# chuyen gia 14 thuc hien bai bao: 1 6 7 9 11 13 21 25 27 30 31
